# %% [markdown]
# # Prueba lectura de datos

# %%
file_txt = 'https://raw.githubusercontent.com/cafigueroao/peru-training-web-2024/blob/main/Notebooks/regex_sum_1994441.txt'

# %%
i = 0
for line in file_txt:
  print(line)
  i = i +1
  if i > 4:
    break
# Out:
# h
# t
# t
# p
# s
